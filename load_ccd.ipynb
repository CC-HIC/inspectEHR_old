# %%
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic


from inspectEHR.utils import load_spec
from inspectEHR.CCD import CCD
from inspectEHR.data_classes import DataRaw, ContMixin, CatMixin

spec = load_spec(os.path.join('data-raw', 'N_DataItems.yml'))

# ccd = CCD(os.path.join('data-raw', 'anon_public_da1000.JSON'), random_sites=True)
ccd = CCD('data-raw/anon_internal.JSON', spec,  random_sites=True)
# Out:
# /Users/steve/projects/ac-inspectEHR/inspectEHR/inspectEHR/CCD.py:69: UserWarning: Quality checking of source JSON not yet implemented.
#   warnings.warn('Quality checking of source JSON not yet implemented.')

# %%
ccd.json2hdf(path='data/anon_internal.h5')
# Out:
# *** Extracting all infotb data from 22534 rows
#
# *** Extracting all 1d data from 22534 rows
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# *** Extracting all 2d data from 22534 rows
# ...........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!!! Value error for {'site_id': 'B', 'episode_id': 14828}
# No objects to concatenate
# .!!! Value error for {'site_id': 'A', 'episode_id': 14833}
# No objects to concatenate
# ......................!!! Value error for {'site_id': 'A', 'episode_id': 15052}
# No objects to concatenate
# .....................!!! Value error for {'site_id': 'B', 'episode_id': 15262}
# No objects to concatenate
# .............................................................................................................................!!! Value error for {'site_id': 'B', 'episode_id': 16513}
# No objects to concatenate
# !!! Value error for {'site_id': 'B', 'episode_id': 16514}
# No objects to concatenate
# !!! Value error for {'site_id': 'E', 'episode_id': 16515}
# No objects to concatenate
# !!! Value error for {'site_id': 'D', 'episode_id': 16516}
# No objects to concatenate
# !!! Value error for {'site_id': 'C', 'episode_id': 16517}
# No objects to concatenate
# !!! Value error for {'site_id': 'B', 'episode_id': 16518}
# No objects to concatenate
# !!! Value error for {'site_id': 'A', 'episode_id': 16519}
# No objects to concatenate
# !!! Value error for {'site_id': 'B', 'episode_id': 16520}
# No objects to concatenate
# .!!! Value error for {'site_id': 'C', 'episode_id': 16521}
# No objects to concatenate
# !!! Value error for {'site_id': 'B', 'episode_id': 16522}
# No objects to concatenate
# !!! Value error for {'site_id': 'B', 'episode_id': 16523}
# No objects to concatenate
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# /Users/steve/projects/ac-inspectEHR/inspectEHR/inspectEHR/CCD.py:215: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['NHICcode', 'item2d', 'meta', 'site_id']]
#
#   self._ccd2hdf(dd, path)
# <class 'pandas.io.pytables.HDFStore'>
# File path: data/anon_internal.h5
# /infotb             frame        (shape->[22534,11])
# /item_1d            frame        (shape->[1,4])
# /item_2d            frame        (shape->[58628696,6])
